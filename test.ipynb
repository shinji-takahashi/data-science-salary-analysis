# %%
import pandas as pd

s = pd.Series(['A','B','C','A'])
s
# Out:
# 0    A
# 1    B
# 2    C
# 3    A
# dtype: str

# %%
mapping = {
    'A':1,
    'B':2,
    'C':3
}

# %%
s.map(mapping)
# Out:
# 0    1
# 1    2
# 2    3
# 3    1
# dtype: int64

# %%
s = pd.Series([10,20,5,3])
s
# Out:
# 0    10
# 1    20
# 2     5
# 3     3
# dtype: int64

# %%
s.where(s>=10 ,0)
# Out:
# 0    10
# 1    20
# 2     0
# 3     0
# dtype: int64

# %%
import numpy as np

s = np.array([10,20,5,3])
s
# Out:
# array([10, 20,  5,  3])

# %%
np.where(s>=10, s, 0)
# Out:
# array([10, 20,  0,  0])
